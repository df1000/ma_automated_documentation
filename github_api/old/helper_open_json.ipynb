# %%
import pandas as pd
import json

# %%
with open('../data/df_repos_sample_250.json') as file:
    loaded_data = json.load(file)

df = pd.DataFrame(data=loaded_data)

# %%
df
# Out:
#             id                 name                     full_name  \
# 0    790713784              logfire              pydantic/logfire
# 1    656099147                 mem0                   mem0ai/mem0
# 2    171020125  Tensorflow-Cookbook  taki0112/Tensorflow-Cookbook
# 3    710159073             ChatGLM3                THUDM/ChatGLM3
# 4    245331808               rezero              majumderb/rezero
# ..         ...                  ...                           ...
# 245  737043169          RAGatouille       AnswerDotAI/RAGatouille
# 246  655413331     HivisionIDPhotos     Zeyi-Lin/HivisionIDPhotos
# 247  106024057    pytorch_geometric    pyg-team/pytorch_geometric
# 248  145848899                panel                 holoviz/panel
# 249     301742              tornado            tornadoweb/tornado
#
#                                             html_url  \
# 0                https://github.com/pydantic/logfire
# 1                     https://github.com/mem0ai/mem0
# ...
