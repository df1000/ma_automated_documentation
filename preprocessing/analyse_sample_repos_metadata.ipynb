# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = '../data/df_repos_sample_250.json'
with open(file_path, 'r') as file:
    loaded_data = json.load(file)

# %%
df = pd.DataFrame(data=loaded_data)

# %%
#df['name'] = df['full_name'].str.split('/').str[0]

# %%
df[df['name'] == 'python-week-2022']
# Out:
#             id              name                     full_name  \
# 130  483433733  python-week-2022  rochacbruno/python-week-2022
#
#                                             html_url  \
# 130  https://github.com/rochacbruno/python-week-2022
#
#                                            description  \
# 130  Template Para a Python Week 2002 - 25 a 29 de ...
#
#                                                    url  \
# 130  https://api.github.com/repos/rochacbruno/pytho...
#
#                                             labels_url            created_at  \
# 130  https://api.github.com/repos/rochacbruno/pytho...  2022-04-19T22:54:34Z
#
#                updated_at             pushed_at  ...  \
# 130  2025-04-11T23:42:13Z  2023-01-19T02:10:13Z  ...
#
#                                                license  allow_forking  \
# 130  {'key': 'unlicense', 'name': 'The Unlicense', ...           True
#
#                                              topics visibility  forks  \
# ...

# %%
file_path = '../data/df_repos_counts_filtered.json'
with open(file_path, 'r') as file:
    loaded_data = json.load(file)

df_to_check = pd.DataFrame(data=loaded_data)

# %%
len(df_to_check)
# Out:
# 189

# %%
df_to_check.head(3)
# Out:
#     repo_owner                 repo_name  source_code_comments  source_code  \
# 0  rochacbruno          python-week-2022                   313          313
# 1     floydhub                 dl-docker                  1044          314
# 2      charlax  professional-programming                  1602         1572
#
#    source_code_cleaned_comments  source_code_cleaned  comments  formatting  \
# 0                           260                  260         0          53
# 1                           850                  263       730          51
# 2                          1313                 1289        30         283
#
#     sum
# 0   313
# 1  1044
# 2  1602

# %%
df_filtered = df[df['name'].isin(df_to_check['repo_name'])]

# %%
len(df_filtered)
# Out:
# 185

# %%
df_filtered['license_type'] = df_filtered['license'].apply(lambda x: list(x.values())[0] if isinstance(x, dict) else None)
# Out:
# /tmp/ipykernel_3884/768333050.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['license_type'] = df_filtered['license'].apply(lambda x: list(x.values())[0] if isinstance(x, dict) else None)

# %%
df_filtered.head(4)
# Out:
#           id    name           full_name  \
# 0   32689863   manim          3b1b/manim
# 1  432968463    helm  stanford-crfm/helm
# 2  775250190  devika    stitionai/devika
# 3  249261267   Ryven    leon-thomm/Ryven
#
#                                 html_url  \
# 0          https://github.com/3b1b/manim
# 1  https://github.com/stanford-crfm/helm
# 2    https://github.com/stitionai/devika
# 3    https://github.com/leon-thomm/Ryven
#
#                                          description  \
# 0       Animation engine for explanatory math videos
# 1  Holistic Evaluation of Language Models (HELM) ...
# 2  Devika is an Agentic AI Software Engineer that...
# 3             Flow-based visual scripting for Python
#
#                                                url  \
# 0          https://api.github.com/repos/3b1b/manim
# 1  https://api.github.com/repos/stanford-crfm/helm
# 2    https://api.github.com/repos/stitionai/devika
# 3    https://api.github.com/repos/leon-thomm/Ryven
#
# ...

# %%
df_filtered['license_type'].value_counts()
# Out:
# license_type
# mit             54
# apache-2.0      39
# other           34
# gpl-3.0         16
# bsd-3-clause    12
# agpl-3.0         6
# gpl-2.0          3
# bsd-2-clause     2
# isc              2
# unlicense        2
# wtfpl            1
# cc-by-sa-4.0     1
# mpl-2.0          1
# Name: count, dtype: int64

# %%
df_filtered[df_filtered['license_type'] == 'other']
# Out:
#             id                           name  \
# 4    185815703                          smplx
# 6     83222441           system-design-primer
# 26   611305072                      ChatPaper
# 29   283046497                        airbyte
# 32     7053637                           mypy
# 33    51117837                         models
# 38     2747590                  python-qrcode
# 46    54376220                 PythonRobotics
# 53     1431547          django-rest-framework
# 57   823745702                   LivePortrait
# 69   140614233                    PySimpleGUI
# 71   614765452                        AutoGPT
# 78    39144867                  docker-stacks
# 99    35517126                           borg
# 101    2835111                    pyinstaller
# 117   26103342                     Flashlight
# 118   10464311                           SASM
# 121   71948498                     localstack
# 122  571186647                        pathway
# ...
